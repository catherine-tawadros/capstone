# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# %%
data, sampling_rate = librosa.load("audio/en/_EHGqmRh9Es__U__S130---0840.140-0846.350.wav")

# %%
plt.figure()
librosa.display.waveshow(data, sr=sampling_rate)
plt.show()

# %%
n_fft = 2048
ft = np.abs(librosa.stft(data[:n_fft], hop_length=n_fft+1))
plt.plot(ft)

# %%
S = librosa.amplitude_to_db(abs(ft))
plt.figure()
librosa.display.specshow(S, sr=sampling_rate, hop_length=512, x_axis='time', y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.show()

# %%
plt.figure(figsize=(12, 4))
mfccs = librosa.feature.mfcc(data, sr=sampling_rate, n_mfcc=13) #computed MFCCs over frames.
librosa.display.specshow(mfccs, sr=sampling_rate, x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.show()
# Out:
# C:\Users\ctawa\AppData\Local\Temp\ipykernel_21472\2611314785.py:2: FutureWarning: Pass y=[-0.00397358 -0.00844414 -0.00809555 ...  0.17050678  0.06695919
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfccs = librosa.feature.mfcc(data, sr=sampling_rate, n_mfcc=13) #computed MFCCs over frames.
